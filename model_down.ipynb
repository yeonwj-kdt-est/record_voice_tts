# %%
import os

# %%
model_id = 'ResembleAI/chatterbox'
download_dir = 'model/models--ResembleAI--chatterbox'
# !hf download {model_id} --local-dir {download_dir}
# Out:
# Fetching 15 files:   0%|                                 | 0/15 [00:00<?, ?it/s]Downloading 'grapheme_mtl_merged_expanded_v1.json' to 'model/models--ResembleAI--chatterbox/.cache/huggingface/download/DRcPeW8zlb71lnnImwJg9PLz_GE=.4b0e4650ba0f98a561ed384dd9043d15046cab4c.incomplete'
#
# grapheme_mtl_merged_expanded_v1.json: 70.0kB [00:00, 47.8MB/s]
# Download complete. Moving file to model/models--ResembleAI--chatterbox/grapheme_mtl_merged_expanded_v1.json
# ...
#
# t3_cfg.pt:   0%|                                    | 0.00/1.06G [00:00<?, ?B/s]Downloading 't3_mtl23ls_v2.safetensors' to 'model/models--ResembleAI--chatterbox/.cache/huggingface/download/MptihmhiAfdbMeNLWlUD5UV2WPs=.b1237586127ce98e7800a68e49938eb5092846862aabcb6e17b2fda7889a6c75.incomplete'
# ...
#
#
# README.md: 5.70kB [00:00, 16.2MB/s]A
# Download complete. Moving file to model/models--ResembleAI--chatterbox/README.md
#
#
# t3_cfg.safetensors:   0%|                           | 0.00/2.13G [00:00<?, ?B/s]
#
#
# ...
